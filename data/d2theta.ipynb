# %%
from numpy import loadtxt,sin,cos,arcsin,pi
from matplotlib.pyplot import plot,figure

# %%
d,di = loadtxt('dspacing_intensity_Allumina.txt',unpack=True)
theta2,ti = loadtxt('2theta_intensity_Allumina.txt',unpack=True)

# %%
l = 1.54
g = l/(2*d)

# %%
plot(theta2,ti,'+-')
plot(360*arcsin(g)/pi,di,'x--')
